# %% [markdown]
# <a href="https://colab.research.google.com/github/Cosamores/cdsi/blob/main/Classifica%C3%A7%C3%A3o_NaivesBayes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files




upload = files.upload()
# Out:
#      <input type="file" id="files-86e290c9-3770-4db5-8696-754b10f0f467" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-86e290c9-3770-4db5-8696-754b10f0f467">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io

risco_credito_csv = upload['risco_credito.csv']
risco_credito = pd.read_csv(io.StringIO(risco_credito_csv.decode('utf-8')))

# %%
array(['alto', 'alto', 'moderado', 'alto', 'baixo', 'baixo', 'alto', 'moderado', 'baixo', 'baixo', 'alto', 'moderado', 'baixo', 'alto'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-45130361.py in <cell line: 0>()
# ----> 1 array(['alto', 'alto', 'moderado', 'alto', 'baixo', 'baixo', 'alto', 'moderado', 'baixo', 'baixo', 'alto', 'moderado', 'baixo', 'alto'])
#
# NameError: name 'array' is not defined

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder_historia = LabelEncoder()
label_encoder_divida = LabelEncoder()
label_encoder_garantia = LabelEncoder()
label_encoder_renda = LabelEncoder()

# %%
X_risco_credito = label_encoder_historia.fit_transform(array)
label_encoder_divida.fit_transform(array)
label_encoder_garantia.fit_transform(array)
label_encoder_renda.fit_transform(array)

# %%
import pickle
with open(caminho+'risco_credito.pkl', 'wb') as f:
    pickle.dump([X_risco_credito, y_risco_credito], f)

# %%
from sklearn.naive_bayes import GaussianNB
naive_risco_credito = GaussianNB()
naive_risco_credito.fit(X_risco_credito, y_risco_credito)

# %%
# História - boa (0), dívida - alta (0), garantia - nenhuma (1), renda - > 35(2)
# História - ruim, dívida - alta (0), garantia - adequada (0), renda -  < 15(0)
previsão_g = naive_risco_credito.predict([0,0,1,2], [2,0,0,0])

# %%
from sklearn.naive_bayes import BernoulliNB
naive_risco_credito_b = BernoulliNB()
naive_risco_credito_b.fit(X_risco_credito, y_risco_credito)
previsão_b = naive_risco_credito.predict([0,0,1,2], [2,0,0,0])

# %%
from sklearn.naive_bayes import MultinomialNB
naive_risco_credito_m = BernoulliNB()
naive_risco_credito_b.fit(X_risco_credito, y_risco_credito)
previsão_b = naive_risco_credito.predict([0,0,1,2], [2,0,0,0])

# %%
naive_risco_credito.classes_
naive_risco_credito.class_count_
naive_risco_credito.class_prior_

# %% [markdown]
# # Base - Credit Data

# %%
upload = files.upload()
# Out:
#      <input type="file" id="files-fd4607e8-5ac1-4d4c-923e-fd8ae0248004" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fd4607e8-5ac1-4d4c-923e-fd8ae0248004">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
credit_data_csv = upload['credit_data.csv']
credit_data = pd.read_csv(io.StringIO(credit_data_csv.decode('utf-8')))
credit_data
# Out:
#       clientid        income        age         loan  default
# 0            1  66155.925095  59.017015  8106.532131        0
# 1            2  34415.153966  48.117153  6564.745018        0
# 2            3  57317.170063  63.108049  8020.953296        0
# 3            4  42709.534201  45.751972  6103.642260        0
# 4            5  66952.688845  18.584336  8770.099235        1
# ...        ...           ...        ...          ...      ...
# 1995      1996  59221.044874  48.518179  1926.729397        0
# 1996      1997  69516.127573  23.162104  3503.176156        0
# 1997      1998  44311.449262  28.017167  5522.786693        1
# 1998      1999  43756.056605  63.971796  1622.722598        0
# 1999      2000  69436.579552  56.152617  7378.833599        0
#
# [2000 rows x 5 columns]

# %%
import pickle
X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_test = pickle.load(credit_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3667012654.py in <cell line: 0>()
#       1 import pickle
# ----> 2 X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_test = pickle.load(credit_data)
#
# TypeError: file must have 'read' and 'readline' attributes

# %%
import io


X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_test = pickle.load(f)
print("Data loaded successfully from uploaded pickle file:")
print("X_risco_credito_treinamento shape:", X_credit_treinamento.shape)
print("y_risco_credito_treinamento shape:",y_credit_treinamento.shape)
print("X_risco_credito_teste shape:", X_credit_teste.shape)
print("y_risco_credito_teste shape:", y_credit_test.shape)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-726961397.py in <cell line: 0>()
#       2
#       3
# ----> 4 X_credit_treinamento, y_credit_treinamento, X_credit_teste, y_credit_test = pickle.load(f)
#       5 print("Data loaded successfully from uploaded pickle file:")
#       6 print("X_risco_credito_treinamento shape:", X_credit_treinamento.shape)
#
# ValueError: I/O operation on closed file.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
previsoes = naive_risco_credito.predict(X_credit_teste)
accuracy_score(y_credit_test, previsoes)

# %%
confusion_matrix(y_credit_test, previsoes)
