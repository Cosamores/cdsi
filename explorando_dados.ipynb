# %% [markdown]
# <a href="https://colab.research.google.com/github/Cosamores/cdsi/blob/main/explorando_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

dados = { "renda": [6.46, 1.50, 0.00, 2.57, 9.90, 6.22],
         "empregos": [1, 1, 0, 1, 2, 3],
          "sexo": ["F", "M", "F", "M", "M", "F"],
          "escolaridade": ["pós-graduação", "fundamental", "médio", "médio", "superior", "médio"]
          }

pme = pd.DataFrame(dados)

print(pme.dtypes)
pme
# Out:
# renda           float64
# empregos          int64
# sexo             object
# escolaridade     object
# dtype: object
#    renda  empregos sexo   escolaridade
# 0   6.46         1    F  pós-graduação
# 1   1.50         1    M    fundamental
# 2   0.00         0    F          médio
# 3   2.57         1    M          médio
# 4   9.90         2    M       superior
# 5   6.22         3    F          médio

# %%
# Dados estatísticos básicos: medidas de tendência central

dados = {"jogador": ["Marcelo", "Pedro", "Marcelo", "Adriano", "Mauro", "Pedro", "Marcelo"],
         "infracao": ["FALTA VIOLENTA", "RECLAMAÇÃO", "FALTA COMUM", "RECLAMAÇAO", "FALTA COMUM", "FALTA VIOLENTA", "RECLAMAÇÃO"],
         "punicao": [4, 1, 3, 2, 4, 4, 2],
         "juiz_A": [4, 1, 3, 2, 4, 4, 2],
         "juiz_B": [2, 1, 4, 1, 1, 5, 6]
         }

df = pd.DataFrame(dados)
print(df)
print("")
print("Média: ", df["punicao"].mean())
print("Mediana: ", df["punicao"].median())
print("Moda: ", df["punicao"].mode().values)
# Out:
#    jogador        infracao  punicao  juiz_A  juiz_B
# 0  Marcelo  FALTA VIOLENTA        4       4       2
# 1    Pedro      RECLAMAÇÃO        1       1       1
# 2  Marcelo     FALTA COMUM        3       3       4
# 3  Adriano      RECLAMAÇAO        2       2       1
# 4    Mauro     FALTA COMUM        4       4       1
# 5    Pedro  FALTA VIOLENTA        4       4       5
# 6  Marcelo      RECLAMAÇÃO        2       2       6
#
# Média:  2.857142857142857
# Mediana:  3.0
# Moda:  [4]

# %%
print("Juiz A")
print("----------")
print("Amplitude: ", df["juiz_A"].max() - df["juiz_A"].min())
print("Variância: ", f"{df['juiz_A'].var():.3f}")
print("Desvio padrão: ", f"{df['juiz_A'].std():.3f}")

print("\nJuiz B")
print("----------")
print("Amplitude: ", df["juiz_B"].max() - df["juiz_B"].min())
print("Variância: ", f"{df['juiz_B'].var():.3f}")
print("Desvio padrão: ", f"{df['juiz_B'].std():.3f}")
# Out:
# Juiz A
# ----------
# Amplitude:  3
# Variância:  1.476
# Desvio padrão:  1.215
#
# Juiz B
# ----------
# Amplitude:  5
# Variância:  4.476
# Desvio padrão:  2.116
